# %%
import numpy as np
import pandas as pd
import psycopg2 as ps2
from sqlalchemy import create_engine

# %%
def connectToPosgres(connection_string='postgresql://wjqioehfjbhsdj:w1^lso3UBJ*8s!Cv@uplifthero2.cfzekqlrgx9n.us-east-1.rds.amazonaws.com:5432/statewa'):
    print 'PostgresSQL is all good brother'
    return create_engine(connection_string)

# %%
conn = connectToPosgres()
# Out:
# PostgresSQL is all good brother

# %%
query2 = ("""
SELECT 
    date_trunc('day', d.sessiontime)       AS date
    , p.strain_display_name                AS product_name
    , p.generic_strain_id                  AS product_id
    , ROUND(SUM(price))                    AS ttl_sales
    , ROUND(SUM(weight))                   AS ttl_units_sold 
FROM biotrackthc_dispensing AS d 
JOIN products AS p ON p.wa_inventory_id = d.inventoryid
WHERE d.deleted = 0 
    AND d.refunded = 0 
    AND p.generic_strain_id = {}
    AND d.sessiontime > '01-01-2016'
GROUP BY date, product_name, generic_strain_id
LIMIT 5;"""
        ).format(1101)

# %%
query4 = ("""
SET TIME ZONE '-08';
SELECT 
    CAST(date_trunc('day', d.sessiontime) AS DATE) AS date
    , p.strain_display_name                AS product_name
    , p.generic_strain_id                  AS product_id
    , ROUND(SUM(price))                    AS ttl_sales
    , ROUND(SUM(weight))                   AS ttl_units_sold 
FROM biotrackthc_dispensing AS d 
JOIN products AS p ON p.wa_inventory_id = d.inventoryid
WHERE p.generic_strain_id = {}
    AND d.sessiontime > '01-01-2016'
    AND d.refunded is Null
    AND d.deleted = 0
GROUP BY date, product_name, generic_strain_id;"""
        ).format(2)

# %%
print(query2)
# Out:
# SELECT
#     date_trunc('day', d.sessiontime)       AS date
#     , p.strain_display_name                AS product_name
#     , p.generic_strain_id                  AS product_id
#     , ROUND(SUM(price))                    AS ttl_sales
#     , ROUND(SUM(weight))                   AS ttl_units_sold
# FROM biotrackthc_dispensing AS d
# JOIN products AS p ON p.wa_inventory_id = d.inventoryid
# WHERE d.deleted = 0
#     AND d.refunded = 0
#     AND p.generic_strain_id = 1101
#     AND d.sessiontime > '01-01-2016'
# GROUP BY date, product_name, generic_strain_id
# LIMIT 5;

# %%
query3 = """SELECT * FROM biotrackthc_dispensing LIMIT 5;"""

# %%
# %%time
df = pd.read_sql_query(query3, conn)
# Out:
# CPU times: user 18.1 ms, sys: 6.25 ms, total: 24.4 ms
# Wall time: 2.35 s

# %%
# %%time
df2 = pd.read_sql_query(query4, conn)
# Out:
# CPU times: user 36.7 ms, sys: 14 ms, total: 50.6 ms
# Wall time: 8min 55s

# %%
df2
# Out:
#            date product_name  product_id  ttl_sales  ttl_units_sold
# 0    2016-01-01  Sour Diesel           2    10626.0           701.0
# 1    2016-01-02  Sour Diesel           2    16515.0          1082.0
# 2    2016-01-03  Sour Diesel           2     8713.0           583.0
# 3    2016-01-04  Sour Diesel           2    11920.0           688.0
# 4    2016-01-05  Sour Diesel           2    12711.0           709.0
# 5    2016-01-06  Sour Diesel           2    12895.0           720.0
# 6    2016-01-07  Sour Diesel           2    12882.0           774.0
# 7    2016-01-08  Sour Diesel           2    19751.0          1172.0
# 8    2016-01-09  Sour Diesel           2    17600.0          1040.0
# 9    2016-01-10  Sour Diesel           2    10309.0           631.0
# 10   2016-01-11  Sour Diesel           2    11228.0           704.0
# 11   2016-01-12  Sour Diesel           2    10863.0           629.0
# 12   2016-01-13  Sour Diesel           2    12227.0           699.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 17 columns):
# id                        5 non-null int64
# orgid                     5 non-null int64
# weight                    5 non-null float64
# sessiontime               5 non-null datetime64[ns, UTC]
# inventoryid               5 non-null object
# transactionid             5 non-null int64
# location                  5 non-null int64
# price                     5 non-null float64
# usableweight              5 non-null float64
# itemnumber                5 non-null int64
# deleted                   5 non-null int64
# refunded                  0 non-null object
# transactionid_original    5 non-null int64
# inventorytype             5 non-null int64
# created                   5 non-null datetime64[ns]
# terminal_id               0 non-null object
# up_unit_price             0 non-null object
# dtypes: datetime64[ns, UTC](1), datetime64[ns](1), float64(3), int64(8), object(4)
# ...

# %%
df
# Out:
#          id  orgid  weight               sessiontime       inventoryid  \
# 0  53397639    592     0.0 2016-11-29 23:39:21+00:00  6033556720003336
# 1  53423265    369     0.0 2016-11-30 01:41:48+00:00  6033484270042089
# 2  53435544    560     0.0 2016-11-30 02:26:26+00:00  6033505740071980
# 3  53508390    560     0.0 2016-11-30 22:05:34+00:00  6032711860017961
# 4  53547043   1514     0.0 2016-12-01 01:08:44+00:00  6033423970009056
#
#    transactionid  location  price  usableweight  itemnumber  deleted refunded  \
# 0       62512074       548 -30.10           0.0           0        0     None
# 1       62545275       246 -17.06           0.0           0        0     None
# 2       62559470       408 -22.20           0.0           0        0     None
# 3       62688103       408 -19.79           0.0           0        0     None
# 4       62741573      1213 -16.09           0.0           1        0     None
#
# ...

# %%
conn2 = ps2.connect(
            database='statewa', user='wjqioehfjbhsdj',
            password='w1^lso3UBJ*8s!Cv',
            host='uplifthero2.cfzekqlrgx9n.us-east-1.rds.amazonaws.com'
                   )

# %%
cur = conn2.cursor()

# %%
cur.execute(query3)

# %%
cur.fetchall()
# Out:
# [(53547043L,
#   1514L,
#   Decimal('0'),
#   datetime.datetime(2016, 12, 1, 1, 8, 44, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),
#   '6033423970009056',
#   62741573L,
#   1213L,
#   Decimal('-16.09'),
#   Decimal('0'),
#   1L,
#   0,
#   None,
#   62741573L,
#   24,
#   datetime.datetime(2016, 11, 30, 17, 8, 44),
#   None,
#   None),
#  (53567519L,
#   592L,
#   Decimal('0'),
#   datetime.datetime(2016, 12, 1, 2, 24, 12, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),
#   '6032271660004271',
#   62765256L,
#   548L,
#   Decimal('-24.62'),
#   Decimal('0'),
#   0L,
#   0,
#   None,
#   62765256L,
#   24,
#   datetime.datetime(2016, 11, 30, 18, 24, 12),
#   None,
#   None),
#  (53568374L,
#   1787L,
#   Decimal('0'),
#   datetime.datetime(2016, 12, 1, 2, 41, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),
#   '6033519020002131',
#   62766599L,
#   1430L,
#   Decimal('-8.8'),
#   Decimal('0'),
#   0L,
#   0,
#   None,
#   62766599L,
# ...

# %%
cur.close()

# %%
conn2.close()
